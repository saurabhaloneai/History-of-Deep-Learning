# %% [markdown]
# # Still working on this (currently learning what is CDF)
#
# ## Before CDF Lest Go Thorugh Basic Of Probability
#
# > What is random variables ?
#
# - It is a set of possile values from a random experiment.
#
# - Ex. rolling a dice -> set-possible-output-y = {1,2,3,4,5,6} -> so if i pick any random value from the set possible values.
# - That values known as random variable (also sample space).
# - random variable can hold multiple values.
# - and the values is selected randomly through random experiment.
#
# > types of random variables ?
#
# - two types -> Continuous and discrete random variable.
#
# - Continuous random variable :- stock market prices. ex nvidia stock prices -> 100.2, 100.3 (i should have bought it man)
#
# - Discrete random variable :- rolling a dice that generate six discrete values.
#
# > what is probability distributions ?
#
#
#
#
#
#
# ## CDF
#
# -

# %% [markdown]
# # Code

# %%
import torch 
from torch import nn
import numpy as np
import matplotlib.pyplot as plt


X = np.linspace(-10,10)

import numpy as np

def gelu(x):
    return 0.5 * x * (1N + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * x**3)))

# Example usage
x = np.linspace(-10,10)
result = gelu(x)
plt.plot(result)
