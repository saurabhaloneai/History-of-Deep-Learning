# %% [markdown]
# > Before you get into gelu you should know what is CDF ?
#
# - after learning **CDF** i think you can skip it if you want.
# - in short cdf helps gelu to skip negative values.
#
# - -> [text](probability.ipynb) (Link to CDF)

# %% [markdown]
# > Lest understand the gelu
#
# - gelu (gaussian error linear unit), an activation function used in neural networks.
#
# - gelu makes a hard decision by outputting zero for all negative inputs and passing through positive inputs as they are.
#
# - gelu, on the other hand, provides a probabilistic gating mechanism by using the Gaussian CDF to weight the inputs. This gives a smoother transition for input values, particularly around zero.
#
# -  relu and leaky relu, which have a sharp transition at  x = 0 , GELU transitions smoothly, which can lead to better performance.
#
# - gelu considers the input’s probability of being positive, which integrates both the input value and its likelihood of activation.
#
# > Why Use the Gaussian CDF?
#
# - inputs often follow a normal distribution.
#
# - gelu used this distribution of input
#
# - this can result in better performance across various tasks, as the gelu function smoothly blends in.
#
# > computation
#
# - ReLU is very simple and computationally efficient.
#
#  - GELU involves more complex calculations due to the Gaussian CDF, but the approximation helps mitigate this complexity.
#
# > math (approximation )
#
# - for computational efficiency, the GELU function can be approximated as:
#
# $$ \text{GELU}(x) \approx 0.5x \left(1 + \tanh\left(\sqrt{\frac{2}{\pi}} \left(x + 0.044715x^3\right)\right)\right) $$
#
# > uses
#
# - used in bert and gpts

# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np


x = torch.linspace(-10, 10, 100)


relu_output = F.relu(x)  # relu
gelu_output = F.gelu(x)  # gelu


x_np = x.numpy()
relu_output_np = relu_output.numpy()
gelu_output_np = gelu_output.numpy()

# Plot the results
plt.figure(figsize=(12, 6))

# Plot ReLU
plt.subplot(1, 2, 1)
plt.plot(x_np, relu_output_np, label='ReLU')
plt.title('ReLU Activation Function')
plt.xlabel('Input')
plt.ylabel('Output')
plt.grid(True)
plt.legend()

# Plot GELU
plt.subplot(1, 2, 2)
plt.plot(x_np, gelu_output_np, label='GELU', color='orange')
plt.title('GELU Activation Function')
plt.xlabel('Input')
plt.ylabel('Output')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### as you can see the smooth curve around zero in gelu plot that helps gelu in better performance !
