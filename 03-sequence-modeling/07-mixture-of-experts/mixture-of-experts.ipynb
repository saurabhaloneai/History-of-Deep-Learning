# %% [markdown]
# # background
#
# there lots of new models like mistral uses Mixture-of-Experts layer (MoE).
#
# and would recoommend to read paper in just one pass but shold really work thorugh this [blog](https://huggingface.co/blog/moe) by huggingface.
#
# will be covering the short summary from that blog here.
#
# # what is moe ?
#
# the leanring capacity of nn is absorb by the number of partameters it has. so the new trend is training bigger model for small number of epochs than training smaller models for large numbers of epochs.(it is working good)
#
# MOE provides you a way to train the model with less compute and help in scaling.(large models)
#
#
#
# > then what exactly is moe ?
#
#
# it is basically a combination of models, each model is an expert in its specific domain.
# a routing mechanism (gating network) decides which experts to use for each query.
#
# when given a task, the system first decides which experts would be best for that particular task. It then routes the task to the chosen experts. the experts process the task and provide their output. if multiple experts are used, their outputs are combined to produce the final result.
#
# > okay this is it for now i will be back here after going through the transformer by see you space cowboy
#
# ![Cowboy-Bebop-Quotes1.jpeg](attachment:Cowboy-Bebop-Quotes1.jpeg)
