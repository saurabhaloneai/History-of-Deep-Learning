# %% [markdown]
# # Striving for Simplicity: The All Convolutional Net (2014).
#
# > review notes of above paper
#
# - this paper introduce two imp thing first replacing the maxpooling by increasing the size of stride and visulisation of cnn layers.
#
# - it pruposes the all cnn layer in arc.
#
# - also replace FC layers by global avg pooling.
#
# - they acheived the good accuracy even after removing some functions.
#
#
# > Lets talk about vis most imp topic
#
# - vis around 12th layer of their CNN model
#
# ![vis_1.png](attachment:vis_1.png)
#
# - the below images shows how network focus on the image of cat.
#
# ![vis-4.png](attachment:vis-4.png)
#
# > how they do it
#
# - for each neuron, if the activation during the forward pass was negative, set the gradient to zero during the backward pass.
#
# - pass only positive gradients back through the network, meaning only the neurons that had positive activations will part of gradient flow.
#
# ![vis_0.png](attachment:vis_0.png)
